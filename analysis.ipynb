# %%
import pandas_datareader as pdr
import pandas as pd
import numpy as np
import datetime as dt

# %%
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2022, 11, 1)
usdcad = pdr.DataReader("DEXCAUS", 'fred', start, end)

# %%
var_exp_dict = {}

var_exp_df = pd.DataFrame()

var_exp = ['dhhngsp','dcoilwtico','dcoilbrenteu', 'will5000prfc','dpropanembtx','dhoilnyh','willresipr',
           'vixcls', 'dexuseu', 'dexusuk', 'dexchus', 'dexjpus', 'dexkous',
           'dexmxus', 'dexinus', 'dexvzus', 'dexbzus', 'dexszus', 'RAILFRTCARLOADSD11', 
          ]

for i in var_exp:
    # téléchargement sur la fed américaine à l'aide de pandas datareader
    var_exp_dict[i] = pdr.DataReader(i.upper(), 'fred', start, end)
    if var_exp_df.empty:
        var_exp_df = var_exp_dict[i]
    else:
        var_exp_df = var_exp_df.join(var_exp_dict[i])
    var_exp_dict[i].ffill(inplace=True)

# %%
var_exp_dict_2 = var_exp_dict

# %%
var_exp_dict_2[var_exp[0]]
# Out:
#             DHHNGSP
# DATE
# 2000-01-03      NaN
# 2000-01-04     2.16
# 2000-01-05     2.17
# 2000-01-06     2.18
# 2000-01-07     2.19
# ...             ...
# 2022-10-26     5.28
# 2022-10-27     5.30
# 2022-10-28     5.02
# 2022-10-31     5.02
# 2022-11-01     4.57
#
# [5962 rows x 1 columns]

# %%
var_exp_df = usdcad
for i in var_exp:
    # téléchargement sur la fed américaine à l'aide de pandas datareader
    var_exp_dict_2[i].pct_change()
    var_exp_dict_2[i]= var_exp_dict_2[i]
    var_exp_df[i] = var_exp_dict_2[i][i.upper()]
    #var_exp_dict[i] = np.array(var_exp_dict[i])

# %%
var_exp_df.ffill(inplace=True)
var_exp_df.count()
# Out:
# DEXCAUS         5955
# dhhngsp         5954
# dcoilwtico      5954
# dcoilbrenteu    5954
# will5000prfc    5955
# dpropanembtx    5954
# dhoilnyh        5954
# willresipr      5955
# vixcls          5955
# dexuseu         5955
# dexusuk         5955
# dexchus         5955
# dexjpus         5955
# dexkous         5955
# dexmxus         5955
# dexinus         5955
# dexvzus         5955
# dexbzus         5955
# dexszus         5955
# USRECD          5955
# EURORECD        5955
# JPNRECDP        5955
# dtype: int64

# %%
var_exp_df.ffill(inplace=True)
var_exp_df.dropna(inplace=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
var_exp_df.corr()
# Out:
#                DEXCAUS   dhhngsp  dcoilwtico  dcoilbrenteu  will5000prfc  \
# DEXCAUS       1.000000 -0.222469   -0.837411     -0.829083      0.072251
# dhhngsp      -0.222469  1.000000    0.267972      0.166501     -0.255443
# dcoilwtico   -0.837411  0.267972    1.000000      0.982336      0.164499
# dcoilbrenteu -0.829083  0.166501    0.982336      1.000000      0.192642
# will5000prfc  0.072251 -0.255443    0.164499      0.192642      1.000000
# dexmxus      -0.652304 -0.176800 -0.037409 -0.029152
# dexinus      -0.555804 -0.215094 -0.017352  0.036774
# dexvzus      -0.174149 -0.064467 -0.133779 -0.145402
# dexbzus      -0.299976 -0.166290 -0.042954 -0.191822
# dexszus       1.000000  0.191770  0.104536 -0.206100
# USRECD        0.191770  1.000000  0.405556  0.350853
# EURORECD      0.104536  0.405556  1.000000  0.260752
# JPNRECDP     -0.206100  0.350853  0.260752  1.000000
#
# [22 rows x 22 columns]

# %%
var_dep_df = var_exp_df.pop('DEXCAUS')

# %%
start = var_exp_df.index[0].date()
end = var_exp_df.index[-1].date()
print(start, end)
# Out:
# 2000-01-04 2022-10-28

# %%
var_dep = np.array(var_dep_df)
var_exp = np.array(var_exp_df)

# %%
X_train, x_test, y_train, y_test =train_test_split(var_exp, var_dep, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-6.56663726e-04,  5.25269743e-04, -2.43988724e-03,  1.65838497e-06,
#         6.05189395e-02, -1.97058474e-02, -7.62112336e-04, -5.05623485e-04,
#        -3.22002442e-01, -1.37232755e-02,  2.59589566e-02,  1.89785172e-03,
#        -1.43388867e-05, -3.35830744e-03,  5.73031936e-03, -1.02316990e-08,
#         1.56230317e-02,  8.91370528e-02, -1.05238964e-02,  4.81581282e-02,
#         2.04451099e-02])

# %%
coeffs = []

for i, coeff in enumerate(model.coef_[1:]):
    coeffs += [[var_exp_df.columns[i], coeff]]

# %%
coeffs_df = pd.DataFrame(coeffs)
coeffs_df.columns = ['Variable', 'Coefficient']
coeffs_df.sort_values(by='Coefficient', ascending=True, inplace=True)
coeffs_df.set_index('Variable', inplace=True)

# %%
coeffs_df
# Out:
#                Coefficient
# Variable
# vixcls       -3.220024e-01
# dpropanembtx -1.970585e-02
# dexuseu      -1.372328e-02
# dexszus      -1.052390e-02
# dexkous      -3.358307e-03
# dcoilwtico   -2.439887e-03
# dhoilnyh     -7.621123e-04
# willresipr   -5.056235e-04
# dexjpus      -1.433889e-05
# dexinus      -1.023170e-08
# dcoilbrenteu  1.658385e-06
# dhhngsp       5.252697e-04
# dexchus       1.897852e-03
# dexmxus       5.730319e-03
# dexvzus       1.562303e-02
# EURORECD      2.044511e-02
# dexusuk       2.595896e-02
# USRECD        4.815813e-02
# will5000prfc  6.051894e-02
# dexbzus       8.913705e-02

# %%
start = dt.datetime(1998, 2, 1)
end = dt.datetime.today()
usdcad = pdr.DataReader("DEXCAUS", 'fred', start, end)

# %%
usdcad.ffill(inplace=True)
usdcad.to_csv('data/dataset/usdcad.csv')

# %%
model.score(x_test, y_test)
# Out:
# 0.9558547149650763

# %%
var_exp_df
# Out:
#             dhhngsp  dcoilwtico  dcoilbrenteu  will5000prfc  dpropanembtx  \
# DATE
# 2000-01-04     2.16       25.56         23.95      13168.48         0.423
# 2000-01-05     2.17       24.65         23.72      13178.53         0.426
# 2000-01-06     2.18       24.79         23.55      13134.23         0.460
# 2000-01-07     2.19       24.79         23.35      13497.01         0.468
# 2000-01-10     2.20       24.71         22.77      13722.70         0.468
# ...             ...         ...           ...           ...           ...
# 2022-10-24     4.81       86.12         91.57      37805.51         0.838
# 2022-10-25     5.17       86.93         91.76      38502.58         0.850
# 2022-10-26     5.28       89.39         92.93      38261.62         0.873
# 2022-10-27     5.30       89.06         94.17      38071.34         0.865
# 2022-10-28     5.02       87.85         94.64      38952.71         0.873
#
#             dhoilnyh  willresipr  vixcls  dexuseu  dexusuk  ...  dexjpus  \
# DATE                                                        ...
# 2000-01-04     0.687       76.93   27.01   1.0309   1.6370  ...   103.09
# 2000-01-05     0.671       77.27   26.41   1.0335   1.6415  ...   103.77
# 2000-01-06     0.675       78.58   25.73   1.0324   1.6475  ...   105.19
# 2000-01-07     0.660       80.32   21.72   1.0294   1.6384  ...   105.17
# 2000-01-10     0.660       81.34   21.71   1.0252   1.6374  ...   105.28
# ...              ...         ...     ...      ...      ...  ...      ...
# 2022-10-24     4.122      225.67   29.85   0.9874   1.1295  ...   148.76
# 2022-10-25     4.044      234.75   28.46   0.9959   1.1469  ...   147.85
# 2022-10-26     4.230      233.87   27.28   1.0068   1.1615  ...   146.50
# 2022-10-27     4.419      233.72   27.39   0.9985   1.1574  ...   146.02
# 2022-10-28     4.540      238.97   25.75   0.9934   1.1573  ...   147.68
#
#             dexkous  dexmxus  dexinus  dexvzus  dexbzus  dexszus  USRECD  \
# DATE
# 2000-01-04  1122.50    9.457    43.55   0.6503   1.8405   1.5565       0
# 2000-01-05  1135.00    9.535    43.55   0.6515   1.8560   1.5526       0
# 2000-01-06  1146.50    9.567    43.55   0.6503   1.8400   1.5540       0
# 2000-01-07  1138.00    9.520    43.55   0.6508   1.8310   1.5623       0
# 2000-01-10  1133.50    9.445    43.55   0.6518   1.8190   1.5704       0
# ...             ...      ...      ...      ...      ...      ...     ...
# 2022-10-24  1439.14   19.945    82.68   8.3866   5.2768   1.0007       0
# 2022-10-25  1432.46   19.867    82.44   8.3825   5.2898   0.9961       0
# 2022-10-26  1425.68   19.866    82.73   8.3886   5.3228   0.9865       0
# 2022-10-27  1419.00   19.838    82.36   8.4297   5.2839   0.9899       0
# 2022-10-28  1421.67   19.824    82.33   8.5041   5.3547   0.9968       0
#
#             EURORECD  JPNRECDP
# DATE
# 2000-01-04       0.0       0.0
# 2000-01-05       0.0       0.0
# 2000-01-06       0.0       0.0
# 2000-01-07       0.0       0.0
# 2000-01-10       0.0       0.0
# ...              ...       ...
# 2022-10-24       0.0       0.0
# 2022-10-25       0.0       0.0
# 2022-10-26       0.0       0.0
# 2022-10-27       0.0       0.0
# 2022-10-28       0.0       0.0
#
# [5954 rows x 21 columns]
